# %% [markdown]
# # creating a dataframe using pandas

# %%
import pandas as pd

k1 = pd.Series([1,2])
k2 = pd.Series(["mini", "mayo"])
# framing series objects into data
df = pd.DataFrame([k1,k2])
# show the data frame
df
# Out:
#       0     1
# 0     1     2
# 1  mini  mayo

# %%
#importing data with pandas
import pandas as pd
  
# Read IND_data.csv into a DataFrame, assigned to df
df = pd.read_csv(r"C:\Users\Mini\Downloads\data-master\police-deaths\all_data.csv")
  
# Prints the first 5 rows of a DataFrame as default
df.head()
# Out:
#                        person  \
# 0     Constable Darius Quimby
# 1  Sheriff Cornelius Hogeboom
# 2  Deputy Sheriff Isaac Smith
# 3      Marshal Robert Forsyth
# 4      Sheriff Robert Maxwell
#
#                                                 dept  \
# 0               Albany County Constable's Office, NY
# 1               Columbia County Sheriff's Office, NY
# 2        Westchester County Sheriff's Department, NY
# 3  United States Department of Justice - United S...
# 4             Greenville County Sheriff's Office, SC
#
#                                eow                    cause
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
# 2      EOW: Thursday, May 17, 1792  Cause of Death: Gunfire
# 3  EOW: Saturday, January 11, 1794  Cause of Death: Gunfire
# 4   EOW: Sunday, November 12, 1797  Cause of Death: Gunfire

# %%
# Prints no. of rows and columns of a DataFrame
df.shape
# Out:
# (22800, 4)

# %% [markdown]
# # Indexing DataFrames with Pandas

# %%
# prints first 5 rows and every column which replicates df.head()
df.iloc[0:5,:]
# Out:
#                        person  \
# 0     Constable Darius Quimby
# 1  Sheriff Cornelius Hogeboom
# 2  Deputy Sheriff Isaac Smith
# 3      Marshal Robert Forsyth
# 4      Sheriff Robert Maxwell
#
#                                                 dept  \
# 0               Albany County Constable's Office, NY
# 1               Columbia County Sheriff's Office, NY
# 2        Westchester County Sheriff's Department, NY
# 3  United States Department of Justice - United S...
# 4             Greenville County Sheriff's Office, SC
#
#                                eow                    cause
# 0     EOW: Monday, January 3, 1791  Cause of Death: Gunfire
# 1  EOW: Saturday, October 22, 1791  Cause of Death: Gunfire
# 2      EOW: Thursday, May 17, 1792  Cause of Death: Gunfire
# 3  EOW: Saturday, January 11, 1794  Cause of Death: Gunfire
# 4   EOW: Sunday, November 12, 1797  Cause of Death: Gunfire

# %%
# prints entire rows and columns
df.iloc[:,:]
# Out:
#                            person  \
# 0         Constable Darius Quimby
# 1      Sheriff Cornelius Hogeboom
# 2      Deputy Sheriff Isaac Smith
# 3          Marshal Robert Forsyth
# 4          Sheriff Robert Maxwell
# ...                           ...
# 22795                    K9 Bruno
# 22796                    K9 Lazer
# 22797                    K9 Tyson
# 22798                    K9 Credo
# 22799                   K9 Roscoe
#
#                                                     dept  \
# 0                   Albany County Constable's Office, NY
# 1                   Columbia County Sheriff's Office, NY
# 2            Westchester County Sheriff's Department, NY
# 3      United States Department of Justice - United S...
# 4                 Greenville County Sheriff's Office, SC
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# ...

# %%
# prints from 5th rows and first 5 columns
df.iloc[5:,:5]
# Out:
#                                 person  \
# 5      High Sheriff John Caldwell Cook
# 6         Watchman Christian Luswanger
# 7         Deputy Sheriff John A. Gooch
# 8       Deputy Sheriff Ebenezer Parker
# 9        Night Watchman George Workner
# ...                                ...
# 22795                         K9 Bruno
# 22796                         K9 Lazer
# 22797                         K9 Tyson
# 22798                         K9 Credo
# 22799                        K9 Roscoe
#
#                                                     dept  \
# 5                Mecklenburg County Sheriff's Office, NC
# 6                                New York City Watch, NY
# 7             Livingston County Sheriff's Department, KY
# 8                 Cumberland County Sheriff's Office, ME
# 9                   Baltimore City Police Department, MD
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# ...

# %% [markdown]
# # Pandas Plotting

# %%
# import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['E001', 'M', 34, 123, 'Normal', 350],
        ['E002', 'F', 40, 114, 'Overweight', 450],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]
  
# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['EMPID', 'Gender', 
                                    'Age', 'Sales',
                                    'BMI', 'Income'] )
  
# create histogram for numeric data
df.hist()
  
# show plot
plt.show()
