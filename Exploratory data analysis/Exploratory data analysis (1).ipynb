# %%
#imported the dataset from the local files
import pandas as pd
Df = pd.read_csv(r"C:\Users\Mini\Downloads\data-master\nutrition-studies\raw_anonymized_data.csv")

# %%
#Pandas in python provide an interesting method describe(). 
#The describe function applies basic statistical computations on the dataset like extreme values, count of data points standard deviation etc.
#Any missing value or NaN value is automatically skipped. describe() function gives a good picture of distribution of data.
Df.describe()
# Out:
#                 ID  BREAKFASTSANDWICHFREQ  BREAKFASTSANDWICHQUAN   EGGSFREQ  \
# count    54.000000              54.000000              54.000000  54.000000
# mean   1082.944444               2.907407               1.037037   4.777778
# std      54.289725               2.002532               0.190626   2.006279
# min    1001.000000               1.000000               1.000000   1.000000
# 25%    1043.250000               1.250000               1.000000   4.000000
# 50%    1075.500000               2.000000               1.000000   4.000000
# 75%    1126.750000               4.000000               1.000000   6.750000
# max    1192.000000               9.000000               2.000000   9.000000
#
#         EGGSQUAN  YOGURTFREQ  YOGURTQUAN  COTTAGECHEESEFREQ  \
# count  54.000000   54.000000   54.000000          54.000000
# mean    2.166667    5.111111    2.555556           1.944444
# std     0.770934    2.567332    0.537874           1.139624
# ...

# %%
#value_counts() which can get count of each category in a categorical attributed series of values. 
Df["COTTAGECHEESEQUAN"].value_counts()
# Out:
# 2    38
# 1    12
# 3     4
# Name: COTTAGECHEESEQUAN, dtype: int64

# %%
#We can easily figure out outliers by using boxplots.
import matplotlib.pyplot as plt
x=list(Df.YOGURTQUAN)
y = list(Df.EGGSQUAN)
plt.boxplot(x,y)
plt.show()

# %%
#Grouping data
Df.groupby(['BREAKFASTSANDWICHFREQ', 'CREAMCHEESEFREQ']).mean()
# Out:
#                                                 ID  BREAKFASTSANDWICHQUAN  \
# BREAKFASTSANDWICHFREQ CREAMCHEESEFREQ
# 1                     1                1093.875000                    1.0
#                       2                1073.250000                    1.0
#                       4                1096.500000                    1.0
# 2                     1                1166.000000                    1.0
#                       2                1074.666667                    1.0
#                       3                1086.000000                    1.0
#                       4                1043.666667                    1.0
#                       5                1082.500000                    1.0
#                       8                1102.000000                    1.0
# 3                     1                1019.000000                    1.0
#                       2                1137.000000                    1.0
# ...

# %%
Df.describe()
# Out:
#                 ID  BREAKFASTSANDWICHFREQ  BREAKFASTSANDWICHQUAN   EGGSFREQ  \
# count    54.000000              54.000000              54.000000  54.000000
# mean   1082.944444               2.907407               1.037037   4.777778
# std      54.289725               2.002532               0.190626   2.006279
# min    1001.000000               1.000000               1.000000   1.000000
# 25%    1043.250000               1.250000               1.000000   4.000000
# 50%    1075.500000               2.000000               1.000000   4.000000
# 75%    1126.750000               4.000000               1.000000   6.750000
# max    1192.000000               9.000000               2.000000   9.000000
#
#         EGGSQUAN  YOGURTFREQ  YOGURTQUAN  COTTAGECHEESEFREQ  \
# count  54.000000   54.000000   54.000000          54.000000
# mean    2.166667    5.111111    2.555556           1.944444
# std     0.770934    2.567332    0.537874           1.139624
# ...
